# %%
import numpy as np
import os
import json
import matplotlib.pyplot as plt
import seaborn as sb

# %%
dir1 = os.path.abspath("outputs")
task3_dir = os.path.join(dir1, "task3")
task3_sim_files = sorted([os.path.join(task3_dir, k) for k in os.listdir(os.path.join(task3_dir)) if "sim_matrix" in k and ".txt" in k])
for file in task3_sim_files:
    name = file.rsplit('/', 1)[-1]
    file_name = name.rsplit('.', 1)[0]
    print(file_name)
    sim_matrix = np.array(json.loads(json.load(open(file, "r"))))
    fig, ax = plt.subplots(figsize=(20, 20))
    sb.heatmap(sim_matrix)
    print(sim_matrix)
    fig1 = plt.gcf()
    plt.show()
    plt.draw()
    fig1.savefig('./output_plot/task3/' + file_name + '.png', dpi=100)
# Out:
# dot_pdt_sim_matrix_1
# [[12.93877551  8.02040816  9.48571429 ...  8.65714286  8.
#    8.50549451]
#  [ 8.02040816 16.81632653  9.54285714 ...  7.22857143  8.
#    6.04395604]
#  [ 9.48571429  9.54285714 20.18       ... 10.4        11.33333333
#   10.72307692]
#  ...
#  [ 8.65714286  7.22857143 10.4        ... 16.64        9.9
#    8.61538462]
#  [ 8.          8.         11.33333333 ...  9.9        16.16666667
#    8.51282051]
#  [ 8.50549451  6.04395604 10.72307692 ...  8.61538462  8.51282051
#   15.66863905]]
# dot_pdt_sim_matrix_2
# [[13.18659993  3.15673166  1.61956583 ...  1.06900353  1.17718491
#    1.46770919]
#  [ 3.15673166 16.76973252  2.3000153  ...  1.52041938  2.29536416
#    0.91606821]
#  [ 1.61956583  2.3000153   8.08263133 ...  1.54664307  1.48942944
#    1.86084747]
#  ...
#  [ 1.06900353  1.52041938  1.54664307 ... 18.94389526  3.4475027
#    2.21278273]
#  [ 1.17718491  2.29536416  1.48942944 ...  3.4475027  14.71456467
#    1.7417596 ]
#  [ 1.46770919  0.91606821  1.86084747 ...  2.21278273  1.7417596
#   16.57884632]]
# dtw_dist_sim_matrix_1
# [[1.         0.63895323 0.65700581 ... 0.5295583  0.52974512 0.61474803]
#  [0.53377167 1.         0.55328069 ... 0.53580597 0.50985567 0.52810837]
#  [0.49580196 0.49147311 1.         ... 0.41714386 0.44880492 0.45448752]
#  ...
#  [0.4346172  0.56798271 0.52347712 ... 1.         0.71977203 0.74513731]
#  [0.46808932 0.5706671  0.5758726  ... 0.73625751 1.         0.73611461]
#  [0.4814798  0.50815543 0.50052804 ... 0.71457612 0.68599919 1.        ]]
# dtw_dist_sim_matrix_2
# [[1.         0.63895323 0.65700581 ... 0.5295583  0.52974512 0.61474803]
#  [0.53377167 1.         0.55328069 ... 0.53580597 0.50985567 0.52810837]
#  [0.49580196 0.49147311 1.         ... 0.41714386 0.44880492 0.45448752]
#  ...
#  [0.4346172  0.56798271 0.52347712 ... 1.         0.71977203 0.74513731]
#  [0.46808932 0.5706671  0.5758726  ... 0.73625751 1.         0.73611461]
#  [0.4814798  0.50815543 0.50052804 ... 0.71457612 0.68599919 1.        ]]
# edit_dist_sim_matrix_1
# [[1.         0.59115965 0.08516331 ... 0.39304488 0.46790024 0.55725643]
#  [0.64140589 1.         0.16203237 ... 0.56964825 0.58766898 0.70897534]
#  [0.23818844 0.20442373 1.         ... 0.38533902 0.39321136 0.53193022]
#  ...
#  [0.50549437 0.60024967 0.39862368 ... 1.         0.78066182 0.83524722]
#  [0.54481728 0.59784886 0.37665834 ... 0.76970089 1.         0.7895339 ]
#  [0.53278708 0.64985901 0.40684364 ... 0.78660676 0.7403717  1.        ]]
# edit_dist_sim_matrix_2
# [[1.         0.59115965 0.08516331 ... 0.39304488 0.46790024 0.55725643]
#  [0.64140589 1.         0.16203237 ... 0.56964825 0.58766898 0.70897534]
#  [0.23818844 0.20442373 1.         ... 0.38533902 0.39321136 0.53193022]
#  ...
#  [0.50549437 0.60024967 0.39862368 ... 1.         0.78066182 0.83524722]
#  [0.54481728 0.59784886 0.37665834 ... 0.76970089 1.         0.7895339 ]
#  [0.53278708 0.64985901 0.40684364 ... 0.78660676 0.7403717  1.        ]]
# lda_cosine_sim_matrix_1
# [[1.         0.96617686 0.96515557 ... 0.97661034 0.99195901 0.99401343]
#  [0.96617686 1.         0.98895908 ... 0.98401224 0.98355471 0.9650531 ]
#  [0.96515557 0.98895908 1.         ... 0.99355398 0.98041282 0.96534503]
#  ...
#  [0.97661034 0.98401224 0.99355398 ... 1.         0.97930442 0.96718868]
#  [0.99195901 0.98355471 0.98041282 ... 0.97930442 1.         0.99603156]
#  [0.99401343 0.9650531  0.96534503 ... 0.96718868 0.99603156 1.        ]]
# lda_cosine_sim_matrix_2
# [[1.         0.70679691 0.85042378 ... 0.60012391 0.39610611 0.60883204]
#  [0.70679691 1.         0.77646861 ... 0.64253534 0.61793311 0.60832651]
#  [0.85042378 0.77646861 1.         ... 0.78887112 0.58417019 0.89802503]
#  ...
#  [0.60012391 0.64253534 0.78887112 ... 1.         0.64093458 0.71738324]
#  [0.39610611 0.61793311 0.58417019 ... 0.64093458 1.         0.53347985]
#  [0.60883204 0.60832651 0.89802503 ... 0.71738324 0.53347985 1.        ]]
# nmf_cosine_sim_matrix_1
# [[1.         0.09195018 0.02756025 ... 0.262234   0.1755653  0.02781046]
#  [0.09195018 1.         0.03495375 ... 0.         0.05465239 0.0173839 ]
#  [0.02756025 0.03495375 1.         ... 0.19637121 0.45031508 0.34010363]
#  ...
#  [0.262234   0.         0.19637121 ... 1.         0.563913   0.20726584]
#  [0.1755653  0.05465239 0.45031508 ... 0.563913   1.         0.01365236]
#  [0.02781046 0.0173839  0.34010363 ... 0.20726584 0.01365236 1.        ]]
# nmf_cosine_sim_matrix_2
# [[1.00000000e+00 8.93655733e-01 7.02626617e-01 ... 0.00000000e+00
#   1.21705494e-02 4.55604363e-03]
#  [8.93655733e-01 1.00000000e+00 7.29954357e-01 ... 0.00000000e+00
#   1.04564712e-02 0.00000000e+00]
#  [7.02626617e-01 7.29954357e-01 1.00000000e+00 ... 9.91574206e-02
#   1.92260092e-02 5.42593869e-01]
#  ...
#  [0.00000000e+00 0.00000000e+00 9.91574206e-02 ... 1.00000000e+00
#   1.12112542e-01 0.00000000e+00]
#  [1.21705494e-02 1.04564712e-02 1.92260092e-02 ... 1.12112542e-01
#   1.00000000e+00 3.44475433e-04]
#  [4.55604363e-03 0.00000000e+00 5.42593869e-01 ... 0.00000000e+00
#   3.44475433e-04 1.00000000e+00]]
# pca_cosine_sim_matrix_1
# [[1.         0.52422396 0.44095422 ... 0.56623654 0.44037666 0.57497381]
#  [0.52422396 1.         0.49267325 ... 0.42123305 0.44695035 0.35373351]
#  [0.44095422 0.49267325 1.         ... 0.53830584 0.58485838 0.56793177]
#  ...
#  [0.56623654 0.42123305 0.53830584 ... 1.         0.62571044 0.53833387]
#  [0.44037666 0.44695035 0.58485838 ... 0.62571044 1.         0.47144776]
#  [0.57497381 0.35373351 0.56793177 ... 0.53833387 0.47144776 1.        ]]
# pca_cosine_sim_matrix_2
# [[1.         0.7237118  0.59230395 ... 0.39182389 0.41774502 0.46260507]
#  [0.7237118  1.         0.66143118 ... 0.45875749 0.55132792 0.42841966]
#  [0.59230395 0.66143118 1.         ... 0.51851549 0.52442947 0.6603071 ]
#  ...
#  [0.39182389 0.45875749 0.51851549 ... 1.         0.67178378 0.52748222]
#  [0.41774502 0.55132792 0.52442947 ... 0.67178378 1.         0.44602588]
#  [0.46260507 0.42841966 0.6603071  ... 0.52748222 0.44602588 1.        ]]
# svd_cosine_sim_matrix_1
# [[1.         0.82000501 0.83781385 ... 0.85408123 0.83624511 0.8519327 ]
#  [0.82000501 1.         0.7835503  ... 0.73767768 0.77428085 0.70935739]
#  [0.83781385 0.7835503  1.         ... 0.82600672 0.85630214 0.84201889]
#  ...
#  [0.85408123 0.73767768 0.82600672 ... 1.         0.85897631 0.8049241 ]
#  [0.83624511 0.77428085 0.85630214 ... 0.85897631 1.         0.80192975]
#  [0.8519327  0.70935739 0.84201889 ... 0.8049241  0.80192975 1.        ]]
# svd_cosine_sim_matrix_2
# [[1.         0.82729787 0.78987032 ... 0.51549975 0.54042419 0.59022542]
#  [0.82729787 1.         0.77676026 ... 0.53883682 0.65380758 0.51315629]
#  [0.78987032 0.77676026 1.         ... 0.64297021 0.6730222  0.7471558 ]
#  ...
#  [0.51549975 0.53883682 0.64297021 ... 1.         0.71411494 0.58802326]
#  [0.54042419 0.65380758 0.6730222  ... 0.71411494 1.         0.55770539]
#  [0.59022542 0.51315629 0.7471558  ... 0.58802326 0.55770539 1.        ]]

# %%
tf_files
# Out:
# ['/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/dot_pdt_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/dot_pdt_sim_matrix_2.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/dtw_dist_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/dtw_dist_sim_matrix_2.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/edit_dist_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/edit_dist_sim_matrix_2.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/lda_cosine_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/lda_cosine_sim_matrix_2.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/nmf_cosine_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/nmf_cosine_sim_matrix_2.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/pca_cosine_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/pca_cosine_sim_matrix_2.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/svd_cosine_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/svd_cosine_sim_matrix_2.txt']

# %%
1`  dsahgfw2
# Out:
# (93, 93)

# %%
pca_main.shape
# Out:
# (60, 60)

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sb.heatmap(pca_svd)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('pca_svd.png', dpi=100)

# %% [markdown]
# ## fig, ax = plt.subplots(figsize=(20, 20))
# sb.heatmap(pca_main)
# fig1 = plt.gcf()
# plt.show()
# plt.draw()
# fig1.savefig('pca_main.png', dpi=100)

# %%
pca_svd
# Out:
# array([[ 1.52969829e-01,  6.64426213e-02,  1.25852796e-01, ...,
#         -3.96592136e-17,  1.67111585e-17, -8.01395563e-17],
#        [-7.00697424e-02, -4.14769220e-01, -1.55772830e-01, ...,
#         -4.53187763e-17,  1.16706162e-16,  2.39104001e-16],
#        [-1.32080262e+00,  1.09749599e-01, -4.96164842e-01, ...,
#          4.91758602e-17, -2.31574660e-16,  6.26813648e-17],
#        ...,
#        [-2.70461708e-01,  7.94276697e-02,  1.38325587e+00, ...,
#          4.04134449e-17,  6.91695728e-17,  1.51681769e-17],
#        [-9.07373017e-01,  8.71147587e-01,  6.69131090e-01, ...,
#          2.18903714e-17, -1.28004738e-17,  8.06949762e-17],
#        [-2.88790781e-02,  8.67908520e-01, -3.42683765e-01, ...,
#          1.19436744e-17, -1.32635541e-16, -6.81905868e-17]])

# %%
dot_nmf = np.array(json.loads(json.load(open(os.path.join(task3_dir, "dot_pdt_nmf_new_30.txt"), "r"))))
dot_main = np.array(json.loads(json.load(open(os.path.join(task3_dir, "dot_pdt_sim_matrix.txt"), "r"))))

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sb.heatmap(dot_nmf)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sb.heatmap(dot_main)
plt.show()

# %%
print(np.amax(dot_main))
# Out:
# 47.225000000000016

# %%
edit_svd = np.array(json.loads(json.load(open(os.path.join(task3_dir, "edit_dist_svd_new_30.txt"), "r"))))
edit_main = np.array(json.loads(json.load(open(os.path.join(task3_dir, "edit_dist_sim_matrix.txt"), "r"))))

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sb.heatmap(edit_svd)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('edit_svd.png', dpi=100)

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sb.heatmap(edit_main)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('edit_main.png', dpi=100)
