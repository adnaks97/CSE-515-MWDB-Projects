# %%
import numpy as np
import os
import json
import matplotlib.pyplot as plt
import seaborn as sb

# %%
dir1 = os.path.abspath("outputs")
task3_dir = os.path.join(dir1, "task3")
task3_sim_files = sorted([os.path.join(task3_dir, k) for k in os.listdir(os.path.join(task3_dir)) if "sim_matrix" in k and ".txt" in k])
for file in task3_sim_files:
    name = file.rsplit('/', 1)[-1]
    file_name = name.rsplit('.', 1)[0]
    print(file_name)
    sim_matrix = np.array(json.loads(json.load(open(file, "r"))))
    fig, ax = plt.subplots(figsize=(20, 20))
    sb.heatmap(sim_matrix)
    print(sim_matrix)
    fig1 = plt.gcf()
    plt.show()
    plt.draw()
    fig1.savefig('./output_plot/task3/' + file_name + '.png', dpi=100)
# Out:
# dot_pdt_sim_matrix_1
# [[13.70408163  9.37244898  9.53571429 ...  9.28991597  9.32142857
#    7.64705882]
#  [ 9.37244898 16.45918367  9.91785714 ... 10.10084034  9.49206349
#    7.66806723]
#  [ 9.53571429  9.91785714 20.46       ... 10.45882353 11.43888889
#   10.76470588]
#  ...
#  [ 9.28991597 10.10084034 10.45882353 ... 18.15224913 11.94117647
#    9.74740484]
#  [ 9.32142857  9.49206349 11.43888889 ... 11.94117647 18.74074074
#   11.50653595]
#  [ 7.64705882  7.66806723 10.76470588 ...  9.74740484 11.50653595
#   16.24221453]]
# dot_pdt_sim_matrix_2
# [[14.39193693  2.13116738  1.42031082 ...  1.57431098  1.01350335
#    1.21551735]
#  [ 2.13116738 14.31586584  1.77839535 ...  1.61049391  1.20180387
#    1.04885262]
#  [ 1.42031082  1.77839535  7.46804498 ...  1.05771945  1.1700211
#    1.35029476]
#  ...
#  [ 1.57431098  1.61049391  1.05771945 ... 10.38020468  1.32771088
#    1.62134813]
#  [ 1.01350335  1.20180387  1.1700211  ...  1.32771088  7.62470065
#    1.35803429]
#  [ 1.21551735  1.04885262  1.35029476 ...  1.62134813  1.35803429
#   11.13023576]]
# dtw_dist_sim_matrix_1
# [[1.         0.63475417 0.45285006 ... 0.31835277 0.27097563 0.39205635]
#  [0.61786837 1.         0.32585016 ... 0.29635271 0.34597666 0.3138803 ]
#  [0.47837948 0.38570495 1.         ... 0.22394241 0.24423908 0.26242364]
#  ...
#  [0.38843941 0.39659748 0.26965936 ... 1.         0.41828069 0.46530901]
#  [0.3575969  0.44915285 0.30144322 ... 0.42865393 1.         0.48208525]
#  [0.42120795 0.37564529 0.26342342 ... 0.43260922 0.44043322 1.        ]]
# dtw_dist_sim_matrix_2
# [[1.         0.63475417 0.45285006 ... 0.31835277 0.27097563 0.39205635]
#  [0.61786837 1.         0.32585016 ... 0.29635271 0.34597666 0.3138803 ]
#  [0.47837948 0.38570495 1.         ... 0.22394241 0.24423908 0.26242364]
#  ...
#  [0.38843941 0.39659748 0.26965936 ... 1.         0.41828069 0.46530901]
#  [0.3575969  0.44915285 0.30144322 ... 0.42865393 1.         0.48208525]
#  [0.42120795 0.37564529 0.26342342 ... 0.43260922 0.44043322 1.        ]]
# edit_dist_sim_matrix_1
# [[1.         0.36841971 0.31775301 ... 0.092214   0.12099993 0.08064367]
#  [0.46759936 1.         0.27907388 ... 0.31175353 0.24025934 0.25039481]
# [[1.         0.79424947 0.48189596 ... 0.59373406 0.40933327 0.36671032]
#  [0.79424947 1.         0.48387157 ... 0.61166532 0.44632082 0.36580831]
#  [0.48189596 0.48387157 1.         ... 0.49411553 0.43547558 0.55306052]
#  ...
#  [0.59373406 0.61166532 0.49411553 ... 1.         0.62242964 0.55042146]
#  [0.40933327 0.44632082 0.43547558 ... 0.62242964 1.         0.67604029]
#  [0.36671032 0.36580831 0.55306052 ... 0.55042146 0.67604029 1.        ]]
# pca_cosine_sim_matrix_2
# [[1.         0.49375413 0.49032302 ... 0.48863057 0.47354032 0.36900646]
#  [0.49375413 1.         0.62631057 ... 0.49466723 0.37885327 0.40766678]
#  [0.49032302 0.62631057 1.         ... 0.51694765 0.52325228 0.6524173 ]
#  ...
#  [0.48863057 0.49466723 0.51694765 ... 1.         0.65436959 0.67453966]
#  [0.47354032 0.37885327 0.52325228 ... 0.65436959 1.         0.66626711]
#  [0.36900646 0.40766678 0.6524173  ... 0.67453966 0.66626711 1.        ]]
# svd_cosine_sim_matrix_1
# [[1.         0.93117719 0.85362921 ... 0.86546559 0.87094112 0.81942175]
#  [0.93117719 1.         0.8219922  ... 0.85964558 0.84091105 0.78620766]
#  [0.85362921 0.8219922  1.         ... 0.82175528 0.84432479 0.8638463 ]
#  ...
#  [0.86546559 0.85964558 0.82175528 ... 1.         0.88527693 0.84556267]
#  [0.87094112 0.84091105 0.84432479 ... 0.88527693 1.         0.91716613]
#  [0.81942175 0.78620766 0.8638463  ... 0.84556267 0.91716613 1.        ]]
# svd_cosine_sim_matrix_2
# [[1.         0.64255145 0.6545345  ... 0.64527434 0.57332475 0.54295028]
#  [0.64255145 1.         0.71231683 ... 0.65113091 0.62741593 0.5601387 ]
#  [0.6545345  0.71231683 1.         ... 0.72814773 0.83607522 0.83635452]
#  ...
#  [0.64527434 0.65113091 0.72814773 ... 1.         0.7854643  0.82308356]
#  [0.57332475 0.62741593 0.83607522 ... 0.7854643  1.         0.8601721 ]
#  [0.54295028 0.5601387  0.83635452 ... 0.82308356 0.8601721  1.        ]]

# %%
tf_files
# Out:
# ['/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/dot_pdt_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/dot_pdt_sim_matrix_2.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/dtw_dist_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/dtw_dist_sim_matrix_2.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/edit_dist_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/edit_dist_sim_matrix_2.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/lda_cosine_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/lda_cosine_sim_matrix_2.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/nmf_cosine_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/nmf_cosine_sim_matrix_2.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/pca_cosine_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/pca_cosine_sim_matrix_2.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/svd_cosine_sim_matrix_1.txt',
#  '/Users/raghav/Documents/MWDB/CSE-515-MWDB-Projects/Phase-2/outputs/task3/svd_cosine_sim_matrix_2.txt']

# %%
1`  dsahgfw2
# Out:
# (93, 93)

# %%
pca_main.shape
# Out:
# (60, 60)

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sb.heatmap(pca_svd)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('pca_svd.png', dpi=100)

# %% [markdown]
# ## fig, ax = plt.subplots(figsize=(20, 20))
# sb.heatmap(pca_main)
# fig1 = plt.gcf()
# plt.show()
# plt.draw()
# fig1.savefig('pca_main.png', dpi=100)

# %%
pca_svd
# Out:
# array([[ 1.52969829e-01,  6.64426213e-02,  1.25852796e-01, ...,
#         -3.96592136e-17,  1.67111585e-17, -8.01395563e-17],
#        [-7.00697424e-02, -4.14769220e-01, -1.55772830e-01, ...,
#         -4.53187763e-17,  1.16706162e-16,  2.39104001e-16],
#        [-1.32080262e+00,  1.09749599e-01, -4.96164842e-01, ...,
#          4.91758602e-17, -2.31574660e-16,  6.26813648e-17],
#        ...,
#        [-2.70461708e-01,  7.94276697e-02,  1.38325587e+00, ...,
#          4.04134449e-17,  6.91695728e-17,  1.51681769e-17],
#        [-9.07373017e-01,  8.71147587e-01,  6.69131090e-01, ...,
#          2.18903714e-17, -1.28004738e-17,  8.06949762e-17],
#        [-2.88790781e-02,  8.67908520e-01, -3.42683765e-01, ...,
#          1.19436744e-17, -1.32635541e-16, -6.81905868e-17]])

# %%
dot_nmf = np.array(json.loads(json.load(open(os.path.join(task3_dir, "dot_pdt_nmf_new_30.txt"), "r"))))
dot_main = np.array(json.loads(json.load(open(os.path.join(task3_dir, "dot_pdt_sim_matrix.txt"), "r"))))

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sb.heatmap(dot_nmf)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sb.heatmap(dot_main)
plt.show()

# %%
print(np.amax(dot_main))
# Out:
# 47.225000000000016

# %%
edit_svd = np.array(json.loads(json.load(open(os.path.join(task3_dir, "edit_dist_svd_new_30.txt"), "r"))))
edit_main = np.array(json.loads(json.load(open(os.path.join(task3_dir, "edit_dist_sim_matrix.txt"), "r"))))

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sb.heatmap(edit_svd)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('edit_svd.png', dpi=100)

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sb.heatmap(edit_main)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('edit_main.png', dpi=100)
